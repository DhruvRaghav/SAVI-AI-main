# %%
! pip install --upgrade --quiet langchain langchain-core langchain-groq langchain-community langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00

# %%
import os
import re
import json
import time
import math
import ast
from google.colab import userdata
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import create_sql_agent
from langchain_openai import ChatOpenAI

# %%
# 1. Environment Setup

# API Key Management
api_keys = [userdata.get(f'GROQ_API_KEY_{i}') for i in range(4)]
current_api_index = 0

def switch_api_key():
    global current_api_index
    if current_api_index < len(api_keys) - 1:
        current_api_index += 1
        os.environ['GROQ_API_KEY'] = api_keys[current_api_index]
        print(f"Switched to API Key {current_api_index}")
    else:
        print("Reached the last API key. No further switching.")
        return False
    return True


# Initialize LLM
os.environ['GROQ_API_KEY'] = api_keys[current_api_index]
llm = ChatGroq(
    temperature=0,
    model_name="llama-3.3-70b-versatile"
)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
    You are an AI assistant specializing in SQL queries for demographic and social data analysis.
    Follow these specific rules when converting natural language to SQL:

    1. Column Naming:
       - CRITICAL: Column names with hyphens MUST be wrapped in double quotes like "Poverty Rate - Marion County"
       - NEVER use underscores to replace hyphens in column names (do NOT use Poverty_Rate_Marion_County)
       - Example correct format: "Poverty Rate - Marion - Black", NOT Poverty_Rate_-_Marion_-_Black
       - When referencing counties, use only the base name in the COUNTY column (e.g., 'Adams' not 'Adams County')
       - For county-specific queries, use COUNTY = 'CountyName' AND STATE = 'StateName'

    2. Percentage Values:
       - Percentage columns store values as whole numbers (e.g., 25.5 means 25.5%)
       - When filtering with percentage thresholds, use the actual number (e.g., > 25, not > 0.25)

    3. Time-based Queries:
       - Always include YEAR column in WHERE clause when years are mentioned
       - CRITICAL: Always include YEAR in the SELECT clause when filtering by years
       - When showing data across years, YEAR should always be the first column in the results
       - For year ranges, use YEAR BETWEEN start_year AND end_year

    4. Column Selection and Result Formatting:
       - Include ONLY the columns specifically mentioned in the query or needed for the answer
       - For "highest" or "top" requests, use ORDER BY column DESC LIMIT n
       - For "lowest" requests, use ORDER BY column ASC LIMIT n
       - When asked for "last n years", order by YEAR DESC LIMIT n
       - When asked for differences between values, ensure proper column name quoting

    5. Database-Specific:
       - Always return exactly what is requested - don't add extra columns unless needed for context
    """),
    ("human", "{input}")
])

# Load Table Metadata
with open("/content/table_metadata.txt", "r") as file:
    table_metadata = json.load(file)

# Connect to SQLite Database
db = SQLDatabase.from_uri("sqlite:///savi_new.db")

# Create SQL Agent
agent_executor = create_sql_agent(llm, db=db, agent_type="openai-tools", verbose=True)

# %%
# 2. Query Processing Functions

def generate_response(user_input):
    """Generate response from LLM with API key switching"""
    formatted_prompt = prompt.format(input=user_input)
    while True:
        try:
            response = llm.invoke([formatted_prompt])
            return response
        except Exception as e:
            error_message = str(e)
            if "rate_limit_reached" in error_message or "Limit" in error_message:
                print("Rate limit reached. Switching API key...")
                if not switch_api_key():
                    return None, "Error: Rate limit reached on last API key. Stopping."
                time.sleep(5)
            else:
                return None, f"Error processing request: {str(e)}"


def query_data(user_input):
    """Process user input and generate SQL query"""
    schema_instruction = "You can choose from the following tables and columns:\n"
    for table_name, meta in table_metadata.items():
        schema_instruction += f"Table: {table_name}\n"
        schema_instruction += f"Description: {meta['description']}\n"
        schema_instruction += "Columns:\n"
        for column_name, column_meta in meta['columns'].items():
            schema_instruction += f"  - {column_name}: {column_meta['description']}\n"
        schema_instruction += "\n"

    full_input = f"{schema_instruction}\n{user_input}"
    try:
        response = generate_response(full_input)
        response_text = response.content if response else ""
        sql_match = re.search(r'```sql\n(.*?)\n```', response_text, re.DOTALL)
        sql_query = sql_match.group(1).strip() if sql_match else response_text.strip()
        query_response = db.run(sql_query)
        return sql_query, query_response
    except Exception as e:
        return None, f"Error processing request: {str(e)}"


def process_query(user_query):
    """Helper function to process queries and handle output"""
    sql_query, response = query_data(user_query)
    if sql_query is None:
        print("Error:", response)
    else:
        print("SQL Query:", sql_query)
        print("Query Response:", response)

# %%
# Load Test Cases
def load_test_cases(file_name):
    try:
        with open(file_name, 'r') as file:
            return json.load(file)
    except Exception as e:
        print(f"Error loading JSON: {e}")
        return []


def normalize_result(result, tolerance=1e-5):
    """Normalize SQL query result for comparison, with tolerance for floating-point values"""
    if isinstance(result, str):
        try:
            result = ast.literal_eval(result)
        except Exception:
            pass

    if isinstance(result, list):
        return [normalize_result(item, tolerance) for item in result]

    if isinstance(result, tuple):
        return [normalize_result(item, tolerance) for item in result]

    if isinstance(result, float):
        return round(result, 5)

    return result

def are_results_equal(result1, result2, tolerance=1e-5):
    """Compare results with proper handling of floating point values"""
    if isinstance(result1, list) and isinstance(result2, list):
        if len(result1) != len(result2):
            return False
        return all(are_results_equal(r1, r2, tolerance) for r1, r2 in zip(result1, result2))

    if isinstance(result1, float) and isinstance(result2, float):
        return abs(result1 - result2) < tolerance

    return result1 == result2


def process_test_case(case, idx, tolerance=1e-5):
    """Run a single test case with improved floating-point comparison"""
    global successful_cases

    user_query = case["user_query"]
    expected_sql = case["expected_sql"]
    expected_result = case["expected_result"]

    try:
        sql_query, result = query_data(user_query)
        normalized_generated_result = normalize_result(result, tolerance)
        normalized_expected_result = normalize_result(expected_result, tolerance)

        if are_results_equal(normalized_generated_result, normalized_expected_result, tolerance):
            successful_cases += 1
            print(f"Test Case {idx}: SUCCESS")
        else:
            print(f"Test Case {idx}: FAIL")
    except Exception as e:
        print(f"Execution Error for Test Case {idx}: {str(e)}")
        print(f"Test Case {idx}: FAIL")
        return

    print("=" * 50)
    print(f"Test Case {idx}")
    print(f"Natural Language Query: {user_query}")
    print(f"Generated SQL Query: {sql_query}")
    print(f"Expected SQL Query: {expected_sql}")
    print(f"Generated Result: {normalized_generated_result}")
    print(f"Expected Result: {normalized_expected_result}")
    print("=" * 50)

# %%
successful_cases = 0

# Load Test Cases
test_file = input("Enter the test case file name: ")
test_cases = load_test_cases(test_file)

# Run Test Cases
for idx, case in enumerate(test_cases, 1):
    process_test_case(case, idx)

total_cases = len(test_cases)
execution_accuracy = (successful_cases / total_cases) * 100 if total_cases > 0 else 0
execution_accuracy = min(execution_accuracy, 100)

# Display Results
print("\n" + "=" * 50)
print(f"Successful Cases: {successful_cases}")
print(f"Total Cases: {total_cases}")
print(f"Execution Accuracy: {execution_accuracy:.2f}%")
print("=" * 50)
print("Final Results:")
print(f"Overall Execution Accuracy (EX): {execution_accuracy:.2f}%")
print("=" * 50)
# Out:
# Enter the test case file name: savi_basic_needs.json
# Test Case 1: SUCCESS
# ==================================================
# Test Case 1
# Natural Language Query: What is the average poverty rate from 2010 to 2012?
# Generated SQL Query: SELECT AVG("Poverty Rate - Indiana State")
# FROM savi_basic_needs_data
# WHERE YEAR BETWEEN 2010 AND 2012;
# Expected SQL Query: SELECT AVG("Poverty Rate - Indiana State") FROM savi_basic_needs_data WHERE "Year" BETWEEN 2010 AND 2012;
# Generated Result: [[14.14678]]
# Expected Result: [[14.14678]]
# ==================================================
# Test Case 2: SUCCESS
# ==================================================
# Test Case 2
# Natural Language Query: Find the year with the highest poverty rate for Black individuals in Marion County
# Generated SQL Query: SELECT YEAR, "Poverty Rate - Marion - Black"
# FROM savi_basic_needs_data
# ORDER BY "Poverty Rate - Marion - Black" DESC
# LIMIT 1;
# Expected SQL Query: SELECT Year, `Poverty Rate - Marion - Black` FROM savi_basic_needs_data ORDER BY `Poverty Rate - Marion - Black` DESC LIMIT 1;
# Generated Result: [[2015, 29.51482]]
# Expected Result: [[2015, 29.51482]]
# ==================================================
# Test Case 3: SUCCESS
# ==================================================
# Test Case 3
# Natural Language Query: What is the highest recorded poverty rate for Asian residents in Marion County?
# Generated SQL Query: SELECT MAX("Poverty Rate - Marion - Asian") AS max_poverty_rate
# FROM savi_basic_needs_data;
# Expected SQL Query: SELECT MAX("Poverty Rate - Marion - Asian") FROM savi_basic_needs_data;
# Generated Result: [[24.51384]]
# Expected Result: [[24.51384]]
# ==================================================
# Test Case 4: SUCCESS
# ==================================================
# Test Case 4
# Natural Language Query: What is the average household income in Marion County?
# Generated SQL Query: SELECT AVG("Median Household Income - Marion County")
# FROM savi_basic_needs_data;
# Expected SQL Query: SELECT AVG("Median Household Income - Marion County") FROM savi_basic_needs_data;
# Generated Result: [[45440.58333]]
# Expected Result: [[45440.58333]]
# ==================================================
# Test Case 5: SUCCESS
# ==================================================
# Test Case 5
# Natural Language Query: Which year had the highest poverty rate in Indiana State and return only the top result?
# Generated SQL Query: SELECT YEAR, "Poverty Rate - Indiana State"
# FROM savi_basic_needs_data
# ORDER BY "Poverty Rate - Indiana State" DESC
# LIMIT 1;
# Expected SQL Query: SELECT Year, "Poverty Rate - Indiana State" FROM savi_basic_needs_data ORDER BY "Poverty Rate - Indiana State" DESC LIMIT 1;
# Generated Result: [[2014, 15.51085]]
# Expected Result: [[2014, 15.51085]]
# ==================================================
# Test Case 6: SUCCESS
# ==================================================
# Test Case 6
# Natural Language Query: What is the highest poverty rate recorded in the entire state?
# Generated SQL Query: SELECT MAX("Poverty Rate - Indiana State")
# FROM savi_basic_needs_data;
# Expected SQL Query: SELECT MAX("Poverty Rate - Indiana State") FROM savi_basic_needs_data;
# Generated Result: [[15.51085]]
# Expected Result: [[15.51085]]
# ==================================================
# Test Case 7: SUCCESS
# ==================================================
# Test Case 7
# Natural Language Query: What is the highest recorded household income for Hispanic residents?
# Generated SQL Query: SELECT MAX("Median Household Income - Hispanic")
# FROM savi_basic_needs_data
# Expected SQL Query: SELECT MAX("Median Household Income - Hispanic") FROM savi_basic_needs_data;
# Generated Result: [[46867]]
# Expected Result: [[46867]]
# ==================================================
# Test Case 8: SUCCESS
# ==================================================
# Test Case 8
# Natural Language Query: What is the average household income in Indiana State?
# Generated SQL Query: SELECT AVG(`Median Household Income - Indiana State`)
# FROM savi_basic_needs_data;
# Expected SQL Query: SELECT AVG("Median Household Income - Indiana State") FROM savi_basic_needs_data;
# Generated Result: [[52010.5]]
# Expected Result: [[52010.5]]
# ==================================================
# Test Case 9: SUCCESS
# ==================================================
# Test Case 9
# Natural Language Query: What is the average poverty rate for White residents in Marion County?
# Generated SQL Query: SELECT AVG("Poverty Rate - Marion - White") AS average_poverty_rate
# FROM savi_basic_needs_data;
# Expected SQL Query: SELECT AVG("Poverty Rate - Marion - White") FROM savi_basic_needs_data;
# Generated Result: [[12.68146]]
# Expected Result: [[12.68146]]
# ==================================================
# Test Case 10: SUCCESS
# ==================================================
# Test Case 10
# Natural Language Query: What was Indiana's state poverty rate in 2021?
# Generated SQL Query: SELECT "Poverty Rate - Indiana State"
# FROM savi_basic_needs_data
# WHERE YEAR = 2021;
# Expected SQL Query: SELECT "Poverty Rate - Indiana State" FROM savi_basic_needs_data WHERE year = 2021;
# Generated Result: [[12.50214]]
# Expected Result: [[12.50214]]
# ==================================================
# Test Case 11: SUCCESS
# ==================================================
# Test Case 11
# Natural Language Query: List years where Marion County's poverty rate was above 20% and show both the poverty rate and median household income.
# Generated SQL Query: SELECT
#     YEAR,
#     "Poverty Rate - Marion County",
#     "Median Household Income - Marion County"
# FROM
#     savi_basic_needs_data
# WHERE
#     "Poverty Rate - Marion County" > 20
# ORDER BY
#     YEAR;
# Expected SQL Query: SELECT Year, `Poverty Rate - Marion County`, `Median Household Income - Marion County` FROM savi_basic_needs_data WHERE `Poverty Rate - Marion County` > 20 ORDER BY Year LIMIT 5;
# Generated Result: [[2013, 20.42224, 42334], [2014, 21.01411, 42378], [2015, 21.09118, 42168], [2016, 20.54037, 43369]]
# Expected Result: [[2013, 20.42224, 42334], [2014, 21.01411, 42378], [2015, 21.09118, 42168], [2016, 20.54037, 43369]]
# ==================================================
# Test Case 12: SUCCESS
# ==================================================
# Test Case 12
# Natural Language Query: Compare poverty rates across all racial groups in Marion County for 2020.
# Generated SQL Query: SELECT
#     "Poverty Rate - Marion - Asian" AS Asian_Poverty_Rate,
#     "Poverty Rate - Marion - Black" AS Black_Poverty_Rate,
#     "Poverty Rate - Marion - Hispanic" AS Hispanic_Poverty_Rate,
#     "Poverty Rate - Marion - White" AS White_Poverty_Rate
# FROM
#     savi_basic_needs_data
# WHERE
#     YEAR = 2020;
# Expected SQL Query: SELECT `Poverty Rate - Marion - Asian` AS Asian_Poverty_Rate, `Poverty Rate - Marion - Black` AS Black_Poverty_Rate, `Poverty Rate - Marion - Hispanic` AS Hispanic_Poverty_Rate, `Poverty Rate - Marion - White` AS White_Poverty_Rate FROM savi_basic_needs_data WHERE YEAR = 2020;
# Generated Result: [[17.63818, 24.60015, 22.94663, 11.07324]]
# Expected Result: [[17.63818, 24.60015, 22.94663, 11.07324]]
# ==================================================
# Test Case 13: SUCCESS
# ==================================================
# Test Case 13
# Natural Language Query: Identify the top five years when the Hispanic poverty rate in Marion County exceeded the Black poverty rate.
# Generated SQL Query: SELECT YEAR, "Poverty Rate - Marion - Hispanic", "Poverty Rate - Marion - Black"
# FROM savi_basic_needs_data
# WHERE "Poverty Rate - Marion - Hispanic" > "Poverty Rate - Marion - Black"
# ORDER BY "Poverty Rate - Marion - Hispanic" - "Poverty Rate - Marion - Black" DESC
# LIMIT 5;
# Expected SQL Query: SELECT year, "Poverty Rate - Marion - Hispanic", "Poverty Rate - Marion - Black" FROM savi_basic_needs_data WHERE "Poverty Rate - Marion - Hispanic" > "Poverty Rate - Marion - Black" ORDER BY "Poverty Rate - Marion - Hispanic" - "Poverty Rate - Marion - Black" DESC LIMIT 5;
# Generated Result: [[2014, 40.15535, 28.99867], [2013, 39.17205, 28.67556], [2012, 36.61632, 27.11018], [2015, 38.88864, 29.51482], [2011, 34.50533, 25.43001]]
# Expected Result: [[2014, 40.15535, 28.99867], [2013, 39.17205, 28.67556], [2012, 36.61632, 27.11018], [2015, 38.88864, 29.51482], [2011, 34.50533, 25.43001]]
# ==================================================
# Test Case 14: FAIL
# ==================================================
# Test Case 14
# Natural Language Query: Show the years where Marion County had both high youth poverty (over 25%) and high elderly poverty (over 10%).
# Generated SQL Query: None
# Expected SQL Query: SELECT year FROM savi_basic_needs_data WHERE "Poverty Rate - Marion - Under 18" > 25 AND "Poverty Rate - Marion - Age 65 and Over" > 10;
# Generated Result: Error processing request: (sqlite3.OperationalError) near "And": syntax error
# [SQL: SELECT YEAR
# From savi_basic_data
# WHERE "Poverty Rate - Marion - Under 18" > 25
#   *And* "Poverty Rate - Marion - Age 65 and Older" > 10]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Expected Result: [[2015], [2016], [2017], [2019]]
# ==================================================
# Test Case 15: SUCCESS
# ==================================================
# Test Case 15
# Natural Language Query: Compare ALICE households across different age groups for years where total poverty households exceeded 45,000.
# Generated SQL Query: SELECT
#     YEAR,
#     "Marion County - ALICE Households by Age Under 25",
#     "Marion County - ALICE Households by Age 25-44",
#     "Marion County - ALICE Households by Age 45-64",
#     "Marion County - ALICE Households by Age 65 and Over"
# FROM
#     savi_basic_needs_data
# WHERE
#     "Marion County - Households by Income Level Below Poverty" > 45000
# ORDER BY
#     YEAR DESC;
# Expected SQL Query: SELECT Year, `Marion County - ALICE Households by Age Under 25`, `Marion County - ALICE Households by Age 25-44`, `Marion County - ALICE Households by Age 45-64`, `Marion County - ALICE Households by Age 65 and Over` FROM savi_basic_needs_data WHERE `Marion County - Households by Income Level Below Poverty` > 45000 ORDER BY Year DESC LIMIT 5;
# Generated Result: [[2021, 8401, 42252, 29551, 33155]]
# Expected Result: [[2021, 8401, 42252, 29551, 33155]]
# ==================================================
# Test Case 16: SUCCESS
# ==================================================
# Test Case 16
# Natural Language Query: Find the top 5 years where Hispanic poverty rate was higher than both White and Asian poverty rates in Marion County.
# Generated SQL Query: SELECT
#     YEAR,
#     "Poverty Rate - Marion - Hispanic",
#     "Poverty Rate - Marion - White",
#     "Poverty Rate - Marion - Asian"
# FROM
#     savi_basic_needs_data
# WHERE
#     "Poverty Rate - Marion - Hispanic" > "Poverty Rate - Marion - White"
#     AND "Poverty Rate - Marion - Hispanic" > "Poverty Rate - Marion - Asian"
# ORDER BY
#     "Poverty Rate - Marion - Hispanic" DESC
# LIMIT 5;
# Expected SQL Query: SELECT Year, `Poverty Rate - Marion - Hispanic`, `Poverty Rate - Marion - White`, `Poverty Rate - Marion - Asian` FROM savi_basic_needs_data WHERE `Poverty Rate - Marion - Hispanic` > `Poverty Rate - Marion - White` AND `Poverty Rate - Marion - Hispanic` > `Poverty Rate - Marion - Asian` ORDER BY `Poverty Rate - Marion - Hispanic` DESC LIMIT 5;
# Generated Result: [[2014, 40.15535, 13.91603, 23.81068], [2013, 39.17205, 13.46899, 24.51384], [2015, 38.88864, 13.94489, 20.13933], [2016, 37.55341, 13.53381, 21.85108], [2012, 36.61632, 13.04908, 22.84421]]
# Expected Result: [[2014, 40.15535, 13.91603, 23.81068], [2013, 39.17205, 13.46899, 24.51384], [2015, 38.88864, 13.94489, 20.13933], [2016, 37.55341, 13.53381, 21.85108], [2012, 36.61632, 13.04908, 22.84421]]
# ==================================================
# Test Case 17: SUCCESS
# ==================================================
# Test Case 17
# Natural Language Query: Show poverty rate in Marion County for the year 2015.
# Generated SQL Query: SELECT
#     "Poverty Rate - Marion County"
# FROM
#     savi_basic_needs_data
# WHERE
#     YEAR = 2015;
# Expected SQL Query: SELECT "Poverty Rate - Marion County" FROM savi_basic_needs_data WHERE Year = 2015;
# Generated Result: [[21.09118]]
# Expected Result: [[21.09118]]
# ==================================================
# Test Case 18: FAIL
# ==================================================
# Test Case 18
# Natural Language Query: What is the average household income in Indiana from 2010 to 2020?
# Generated SQL Query: SELECT
#     YEAR,
#     "Median Household Income - Indiana State"
# FROM
#     savi_basic_needs_data
# WHERE
#     YEAR BETWEEN 2010 AND 2020;
# Expected SQL Query: SELECT AVG("Median Household Income - Indiana State") FROM savi_basic_needs_data WHERE Year BETWEEN 2010 AND 2020;
# Generated Result: [[2010, 47697], [2011, 48393], [2012, 48374], [2013, 48248], [2014, 48737], [2015, 49255], [2016, 50433], [2017, 52182], [2018, 54325], [2019, 56303], [2020, 58235]]
# Expected Result: [[51107.45455]]
# ==================================================
# Test Case 19: SUCCESS
# ==================================================
# Test Case 19
# Natural Language Query: Show poverty rates for Asian residents in Marion County for years after 2015.
# Generated SQL Query: SELECT
#     YEAR,
#     "Poverty Rate - Marion - Asian"
# FROM
#     savi_basic_needs_data
# WHERE
#     YEAR > 2015
# ORDER BY
#     YEAR;
# Expected SQL Query: SELECT Year, "Poverty Rate - Marion - Asian" FROM savi_basic_needs_data WHERE Year > 2015;
# Generated Result: [[2016, 21.85108], [2017, 21.45401], [2018, 23.18274], [2019, 18.3141], [2020, 17.63818], [2021, 14.95447]]
# Expected Result: [[2016, 21.85108], [2017, 21.45401], [2018, 23.18274], [2019, 18.3141], [2020, 17.63818], [2021, 14.95447]]
# ==================================================
# Test Case 20: SUCCESS
# ==================================================
# Test Case 20
# Natural Language Query: How many records show a poverty rate above 15% in Indiana?
# Generated SQL Query: SELECT COUNT(*)
# FROM savi_basic_needs_data
# WHERE "Poverty Rate - Indiana State" > 15;
# Expected SQL Query: SELECT COUNT(*) FROM savi_basic_needs_data WHERE "Poverty Rate - Indiana State" > 15;
# Generated Result: [[3]]
# Expected Result: [[3]]
# ==================================================
# Test Case 21: SUCCESS
# ==================================================
# Test Case 21
# Natural Language Query: Show household income for years between 2012 and 2016 in Marion County.
# Generated SQL Query: SELECT
#     YEAR,
#     "Median Household Income - Marion County"
# FROM
#     savi_basic_needs_data
# WHERE
#     YEAR BETWEEN 2012 AND 2016
# ORDER BY
#     YEAR;
# Expected SQL Query: SELECT Year, "Median Household Income - Marion County" FROM savi_basic_needs_data WHERE Year BETWEEN 2012 AND 2016;
# Generated Result: [[2012, 42603], [2013, 42334], [2014, 42378], [2015, 42168], [2016, 43369]]
# Expected Result: [[2012, 42603], [2013, 42334], [2014, 42378], [2015, 42168], [2016, 43369]]
# ==================================================
#
# ==================================================
# Successful Cases: 19
# Total Cases: 21
# Execution Accuracy: 90.48%
# ==================================================
# Final Results:
# Overall Execution Accuracy (EX): 90.48%
# ==================================================

# %%
successful_cases = 0

# Load Test Cases
test_file = input("Enter the test case file name: ")
test_cases = load_test_cases(test_file)

# Run Test Cases
for idx, case in enumerate(test_cases, 1):
    process_test_case(case, idx)

total_cases = len(test_cases)
execution_accuracy = (successful_cases / total_cases) * 100 if total_cases > 0 else 0
execution_accuracy = min(execution_accuracy, 100)

# Display Results
print("\n" + "=" * 50)
print(f"Successful Cases: {successful_cases}")
print(f"Total Cases: {total_cases}")
print(f"Execution Accuracy: {execution_accuracy:.2f}%")
print("=" * 50)
print("Final Results:")
print(f"Overall Execution Accuracy (EX): {execution_accuracy:.2f}%")
print("=" * 50)
# Out:
# Enter the test case file name: svi_indiana_in.json
# Test Case 1: SUCCESS
# ==================================================
# Test Case 1
# Natural Language Query: List 5 counties that have the highest unemployment rate.
# Generated SQL Query: SELECT COUNTY, EP_UNEMP
# FROM svi_indiana_in
# ORDER BY EP_UNEMP DESC
# LIMIT 5;
# Expected SQL Query: SELECT COUNTY, EP_UNEMP FROM svi_indiana_in ORDER BY EP_UNEMP DESC LIMIT 5;
# Generated Result: [['Lake', 43.6], ['Marion', 35.1], ['Lake', 28.9], ['Lake', 28.6], ['Monroe', 26.2]]
# Expected Result: [['Lake', 43.6], ['Marion', 35.1], ['Lake', 28.9], ['Lake', 28.6], ['Monroe', 26.2]]
# ==================================================
# Test Case 2: SUCCESS
# ==================================================
# Test Case 2
# Natural Language Query: Which counties have a mobile phone penetration rate greater than 70%?
# Generated SQL Query: SELECT COUNTY
# FROM svi_indiana_in
# WHERE EP_MOBILE > 70;
# Expected SQL Query: SELECT COUNTY FROM svi_indiana_in WHERE EP_MOBILE > 70;
# Generated Result: [['Allen'], ['Marion']]
# Expected Result: [['Allen'], ['Marion']]
# ==================================================
# Test Case 3: SUCCESS
# ==================================================
# Test Case 3
# Natural Language Query: Which counties have the largest area in square miles and return the top 3 results?
# Generated SQL Query: SELECT COUNTY, AREA_SQMI
# FROM svi_indiana_in
# ORDER BY AREA_SQMI DESC
# LIMIT 3;
# Expected SQL Query: SELECT COUNTY, AREA_SQMI FROM svi_indiana_in ORDER BY AREA_SQMI DESC LIMIT 3;
# Generated Result: [['Allen', 657.30016], ['LaPorte', 598.28638], ['Jasper', 559.67946]]
# Expected Result: [['Allen', 657.30016], ['LaPorte', 598.28638], ['Jasper', 559.67946]]
# ==================================================
# Test Case 4: SUCCESS
# ==================================================
# Test Case 4
# Natural Language Query: Which county has the highest percentage of single-parent households?
# Generated SQL Query: SELECT COUNTY, EP_SNGPNT
# FROM svi_indiana_in
# ORDER BY EP_SNGPNT DESC
# LIMIT 1;
# Expected SQL Query: SELECT "COUNTY", "EP_SNGPNT" FROM svi_indiana_in ORDER BY "EP_SNGPNT" DESC LIMIT 1;
# Generated Result: [['Lake', 43.7]]
# Expected Result: [['Lake', 43.7]]
# ==================================================
# Test Case 5: SUCCESS
# ==================================================
# Test Case 5
# Natural Language Query: What is the total number of uninsured people across all counties?
# Generated SQL Query: SELECT SUM(E_UNINSUR) AS Total_Uninsured
# FROM svi_indiana_in;
# Expected SQL Query: SELECT SUM("E_UNINSUR") AS "Total Uninsured" FROM svi_indiana_in;
# Generated Result: [[1056352]]
# Expected Result: [[1056352]]
# ==================================================
# Test Case 6: SUCCESS
# ==================================================
# Test Case 6
# Natural Language Query: What is the average total population across all counties?
# Generated SQL Query: SELECT AVG(E_TOTPOP) AS average_total_population
# FROM svi_indiana_in;
# Expected SQL Query: SELECT AVG("E_TOTPOP") FROM svi_indiana_in;
# Generated Result: [[7503.52157]]
# Expected Result: [[7503.52157]]
# ==================================================
# Test Case 7: SUCCESS
# ==================================================
# Test Case 7
# Natural Language Query: Which county has the highest total population? Provide the population count as well?
# Generated SQL Query: SELECT COUNTY, E_TOTPOP
# FROM svi_indiana_in
# ORDER BY E_TOTPOP DESC
# LIMIT 1;
# Expected SQL Query: SELECT COUNTY, E_TOTPOP FROM svi_indiana_in ORDER BY E_TOTPOP DESC LIMIT 1;
# Generated Result: [['Marion', 957337]]
# Expected Result: [['Marion', 957337]]
# ==================================================
# Test Case 8: SUCCESS
# ==================================================
# Test Case 8
# Natural Language Query: Find the total number of people below 150% of the poverty line across all counties.
# Generated SQL Query: SELECT SUM(E_POV150) AS Total_People_Below_150_Percent_Poverty
# FROM svi_indiana_in;
# Expected SQL Query: SELECT SUM("E_POV150") AS "Total People Below 150% Poverty Line" FROM svi_indiana_in;
# Generated Result: [[2789556]]
# Expected Result: [[2789556]]
# ==================================================
# Test Case 9: SUCCESS
# ==================================================
# Test Case 9
# Natural Language Query: What is the highest percentage of people with no high school diploma across all counties?
# Generated SQL Query: SELECT COUNTY, EP_NOHSDP
# FROM svi_indiana_in
# ORDER BY EP_NOHSDP DESC
# LIMIT 1;
# Expected SQL Query: SELECT "COUNTY", "EP_NOHSDP" FROM svi_indiana_in ORDER BY "EP_NOHSDP" DESC LIMIT 1;
# Generated Result: [['LaGrange', 73.9]]
# Expected Result: [['LaGrange', 73.9]]
# ==================================================
# Test Case 10: FAIL
# ==================================================
# Test Case 10
# Natural Language Query: Calculate the average household size across all counties.
# Generated SQL Query: SELECT AVG(E_TOTPOP / E_HH) AS average_household_size
# FROM svi_indiana_in;
# Expected SQL Query: SELECT AVG("E_HH" / ("E_TOTPOP" / "E_HU") * "E_HU") AS "Average Household Size" FROM svi_indiana_in;
# Generated Result: [[2.27549]]
# Expected Result: [[91152031.20836]]
# ==================================================
# Test Case 11: SUCCESS
# ==================================================
# Test Case 11
# Natural Language Query: What is the total population of Adams County?
# Generated SQL Query: SELECT E_TOTPOP
# FROM svi_indiana_in
# WHERE COUNTY = 'Adams';
# Expected SQL Query: SELECT E_TOTPOP FROM svi_indiana_in WHERE COUNTY = 'Adams' AND STATE = 'Indiana';
# Generated Result: [[35544], [4975], [4823], [5352], [3968], [6655], [3337], [6434]]
# Expected Result: [[35544], [4975], [4823], [5352], [3968], [6655], [3337], [6434]]
# ==================================================
# Test Case 12: SUCCESS
# ==================================================
# Test Case 12
# Natural Language Query: Which county has the highest percentage of households with no vehicles?
# Generated SQL Query: SELECT COUNTY, EP_NOVEH
# FROM svi_indiana_in
# ORDER BY EP_NOVEH DESC
# LIMIT 1;
# Expected SQL Query: SELECT COUNTY, EP_NOVEH FROM svi_indiana_in ORDER BY EP_NOVEH DESC LIMIT 1;
# Generated Result: [['LaGrange', 71.8]]
# Expected Result: [['LaGrange', 71.8]]
# ==================================================
# Test Case 13: SUCCESS
# ==================================================
# Test Case 13
# Natural Language Query: Find the average unemployment rate across all counties in Indiana.
# Generated SQL Query: SELECT AVG(EP_UNEMP) AS average_unemployment_rate
# FROM svi_indiana_in;
# Expected SQL Query: SELECT AVG(EP_UNEMP) FROM svi_indiana_in WHERE STATE = 'Indiana';
# Generated Result: [[0.06045]]
# Expected Result: [[0.06045]]
# ==================================================
# Test Case 14: SUCCESS
# ==================================================
# Test Case 14
# Natural Language Query: Find the top 8 counties with the highest percentage of limited English proficiency and their minority population percentage.
# Generated SQL Query: SELECT
#     COUNTY,
#     EP_LIMENG,
#     EP_MINRTY
# FROM
#     svi_indiana_in
# ORDER BY
#     EP_LIMENG DESC
# LIMIT 8;
# Expected SQL Query: SELECT COUNTY, EP_LIMENG, EP_MINRTY FROM svi_indiana_in ORDER BY EP_LIMENG DESC LIMIT 8;
# Generated Result: [['Marion', 39.5, 58.6], ['Marion', 27.1, 49.2], ['Marion', 25.2, 87.8], ['Marion', 24.6, 86.3], ['Marion', 21.4, 56.9], ['Marion', 20.0, 78.7], ['Marion', 17.3, 72.6], ['Marion', 17.2, 47.3]]
# Expected Result: [['Marion', 39.5, 58.6], ['Marion', 27.1, 49.2], ['Marion', 25.2, 87.8], ['Marion', 24.6, 86.3], ['Marion', 21.4, 56.9], ['Marion', 20.0, 78.7], ['Marion', 17.3, 72.6], ['Marion', 17.2, 47.3]]
# ==================================================
# Test Case 15: SUCCESS
# ==================================================
# Test Case 15
# Natural Language Query: Which 5 counties have the highest housing burden among counties with above 50,000 total population?
# Generated SQL Query: SELECT COUNTY, EP_HBURD
# FROM svi_indiana_in
# WHERE E_TOTPOP > 50000
# ORDER BY EP_HBURD DESC
# LIMIT 5;
# Expected SQL Query: SELECT COUNTY, EP_HBURD as housing_burden  FROM svi_indiana_in WHERE E_TOTPOP > 50000 ORDER BY EP_HBURD DESC LIMIT 5;
# Generated Result: [['Marion', 31.4], ['Monroe', 31.0], ['Tippecanoe', 30.3], ['Vigo', 28.6], ['Vanderburgh', 27.8]]
# Expected Result: [['Marion', 31.4], ['Monroe', 31.0], ['Tippecanoe', 30.3], ['Vigo', 28.6], ['Vanderburgh', 27.8]]
# ==================================================
# Test Case 16: SUCCESS
# ==================================================
# Test Case 16
# Natural Language Query: Find the 7 counties with the highest number of households and their corresponding percentage of mobile homes
# Generated SQL Query: SELECT
#   COUNTY,
#   E_HH,
#   EP_MOBILE
# FROM
#   svi_indiana_in
# ORDER BY
#   E_HH DESC
# LIMIT 7;
# Expected SQL Query: SELECT COUNTY, E_HH, EP_MOBILE FROM svi_indiana_in ORDER BY E_HH DESC LIMIT 7;
# Generated Result: [['Marion', 377695, 1.5], ['Lake', 188646, 1.5], ['Allen', 147043, 3.2], ['Hamilton', 123066, 1.6], ['St. Joseph', 104380, 1.6], ['Vanderburgh', 76094, 2.5], ['Elkhart', 72362, 7.0]]
# Expected Result: [['Marion', 377695, 1.5], ['Lake', 188646, 1.5], ['Allen', 147043, 3.2], ['Hamilton', 123066, 1.6], ['St. Joseph', 104380, 1.6], ['Vanderburgh', 76094, 2.5], ['Elkhart', 72362, 7.0]]
# ==================================================
# Test Case 17: SUCCESS
# ==================================================
# Test Case 17
# Natural Language Query: Which 5 counties have the highest combined percentage of unemployment and no high school diploma?
# Generated SQL Query: SELECT
#   COUNTY,
#   EP_UNEMP,
#   EP_NOHSDP,
#   (EP_UNEMP + EP_NOHSDP) AS Combined_Percentage
# FROM
#   svi_indiana_in
# ORDER BY
#   Combined_Percentage DESC
# LIMIT 5;
# Expected SQL Query: SELECT COUNTY, EP_UNEMP as unemployment_pct, EP_NOHSDP as no_diploma_pct, (EP_UNEMP + EP_NOHSDP) FROM svi_indiana_in ORDER BY (EP_UNEMP + EP_NOHSDP) DESC LIMIT 5;
# Generated Result: [['LaGrange', 0.5, 73.9, 74.4], ['LaGrange', 4.7, 68.4, 73.1], ['Daviess', 0.6, 70.5, 71.1], ['Lake', 20.2, 43.8, 64.0], ['LaGrange', 0.0, 63.0, 63.0]]
# Expected Result: [['LaGrange', 0.5, 73.9, 74.4], ['LaGrange', 4.7, 68.4, 73.1], ['Daviess', 0.6, 70.5, 71.1], ['Lake', 20.2, 43.8, 64.0], ['LaGrange', 0.0, 63.0, 63.0]]
# ==================================================
# Test Case 18: SUCCESS
# ==================================================
# Test Case 18
# Natural Language Query: Calculate the average poverty rate for counties with a population over 100,000.
# Generated SQL Query: SELECT AVG(EP_POV150)
# FROM svi_indiana_in
# WHERE E_TOTPOP > 100000;
# Expected SQL Query: SELECT AVG(EP_POV150) as avg_poverty_rate FROM svi_indiana_in WHERE E_TOTPOP > 100000;
# Generated Result: [[22.12353]]
# Expected Result: [[22.12353]]
# ==================================================
# Test Case 19: SUCCESS
# ==================================================
# Test Case 19
# Natural Language Query: List the counties where more than 40% of the population is over 65 years old and mention the percentages.
# Generated SQL Query: SELECT
#   COUNTY,
#   EP_AGE65
# FROM
#   svi_indiana_in
# WHERE
#   EP_AGE65 > 40
# ORDER BY
#   EP_AGE65 DESC;
# Expected SQL Query: SELECT COUNTY, EP_AGE65 FROM svi_indiana_in WHERE EP_AGE65 > 40 ORDER BY EP_AGE65 DESC;
# Generated Result: [['Vanderburgh', 100.0], ['Allen', 78.9], ['Lake', 43.5], ['LaPorte', 40.6]]
# Expected Result: [['Vanderburgh', 100.0], ['Allen', 78.9], ['Lake', 43.5], ['LaPorte', 40.6]]
# ==================================================
# Test Case 20: SUCCESS
# ==================================================
# Test Case 20
# Natural Language Query: Find the county with the highest percentage of households with housing cost burden.
# Generated SQL Query: SELECT COUNTY, EP_HBURD
# FROM svi_indiana_in
# ORDER BY EP_HBURD DESC
# LIMIT 1;
# Expected SQL Query: SELECT COUNTY, EP_HBURD FROM svi_indiana_in ORDER BY EP_HBURD DESC LIMIT 1;
# Generated Result: [['Tippecanoe', 88.5]]
# Expected Result: [['Tippecanoe', 88.5]]
# ==================================================
# Test Case 21: SUCCESS
# ==================================================
# Test Case 21
# Natural Language Query: Calculate the average percentage of people with a disability for counties with population under 50,000.
# Generated SQL Query: SELECT AVG(EP_DISABL)
# FROM svi_indiana_in
# WHERE E_TOTPOP < 50000;
# Expected SQL Query: SELECT AVG(EP_DISABL) as avg_disability_percentage FROM svi_indiana_in WHERE E_TOTPOP < 50000;
# Generated Result: [[10.63316]]
# Expected Result: [[10.63316]]
# ==================================================
# Test Case 22: SUCCESS
# ==================================================
# Test Case 22
# Natural Language Query: Find the county with the highest percentage of multi-unit structures.
# Generated SQL Query: SELECT COUNTY, EP_MUNIT
# FROM svi_indiana_in
# ORDER BY EP_MUNIT DESC
# LIMIT 1;
# Expected SQL Query: SELECT COUNTY, EP_MUNIT FROM svi_indiana_in ORDER BY EP_MUNIT DESC LIMIT 1;
# Generated Result: [['Marion', 87.5]]
# Expected Result: [['Marion', 87.5]]
# ==================================================
# Test Case 23: SUCCESS
# ==================================================
# Test Case 23
# Natural Language Query: Find the county with the highest percentage of households with crowding.
# Generated SQL Query: SELECT COUNTY, EP_CROWD
# FROM svi_indiana_in
# ORDER BY EP_CROWD DESC
# LIMIT 1;
# Expected SQL Query: SELECT COUNTY, EP_CROWD FROM svi_indiana_in ORDER BY EP_CROWD DESC LIMIT 1;
# Generated Result: [['Daviess', 19.0]]
# Expected Result: [['Daviess', 19.0]]
# ==================================================
# Test Case 24: SUCCESS
# ==================================================
# Test Case 24
# Natural Language Query: Find the county with the lowest percentage of people aged 17 and under.
# Generated SQL Query: SELECT COUNTY, EP_AGE17
# FROM svi_indiana_in
# ORDER BY EP_AGE17 ASC
# LIMIT 1;
# Expected SQL Query: SELECT COUNTY, EP_AGE17 FROM svi_indiana_in ORDER BY EP_AGE17 ASC LIMIT 1;
# Generated Result: [['Allen', 0.0]]
# Expected Result: [['Allen', 0.0]]
# ==================================================
#
# ==================================================
# Successful Cases: 23
# Total Cases: 24
# Execution Accuracy: 95.83%
# ==================================================
# Final Results:
# Overall Execution Accuracy (EX): 95.83%
# ==================================================
